# %% [markdown]
# <a href="https://colab.research.google.com/github/17957431/facefusion/blob/master/tonyff_last_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 单图AI换脸！
#
# 可以使用图片去换图片，也可以用图片换视频。
#
# 使用方法，只要依次点击或者全部运行就可以了。运行成功点击网址打开即可使用。软件的具体使用可以参考[使用教程](https://www.tonyisstark.com/1863.html)。
#
#
# 注意事项：默默使用即可，不用分享，谷歌被刷多了开始各种限制了。
#
# 该脚本仅供学习研究，严禁用于违法违规的场景。

# %%
#@title 1.获取代码

tag = 'v3.6.0' #@param ["v3.6.0", ] {allow-input: true}

# !git clone https://github.com/dream80/tonyff.git
# %cd /content/tonyff
# !git checkout {tag}
# Out:
# Cloning into 'tonyff'...
# remote: Enumerating objects: 400, done.
# remote: Counting objects: 100% (171/171), done.
# remote: Compressing objects: 100% (133/133), done.
# remote: Total 400 (delta 63), reused 108 (delta 38), pack-reused 229 (from 1)
# Receiving objects: 100% (400/400), 219.34 KiB | 1.11 MiB/s, done.
# Resolving deltas: 100% (162/162), done.
# /content/tonyff
# HEAD is now at 35ad110 Update installer.py

# %%
#@title 2.安装依赖

# %cd /content/tonyff
# !python install.py --skip-conda --onnxruntime cuda-12.2
# Out:
# /content/tonyff
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 3.9 MB/s eta 0:00:00
# ...
#   Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 5.5 MB/s eta 0:00:00
# ...
#   Using cached importlib_resources-6.4.5-py3-none-any.whl.metadata (4.0 kB)
# ...
#   Using cached jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 4.0 MB/s eta 0:00:00
# ...
#   Using cached packaging-24.1-py3-none-any.whl.metadata (3.2 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.4/149.4 kB 8.2 MB/s eta 0:00:00
# ...
#   Using cached PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#@title 3.运行软件
# !python run.py
# Out:
# IMPORTANT: You are using gradio version 3.50.2, however version 4.29.0 is available, please upgrade.
# --------
# IMPORTANT: You are using gradio version 3.50.2, however version 4.29.0 is available, please upgrade.
# --------
# IMPORTANT: You are using gradio version 3.50.2, however version 4.29.0 is available, please upgrade.
# --------
# IMPORTANT: You are using gradio version 3.50.2, however version 4.29.0 is available, please upgrade.
# --------
# IMPORTANT: You are using gradio version 3.50.2, however version 4.29.0 is available, please upgrade.
# --------
# IMPORTANT: You are using gradio version 3.50.2, however version 4.29.0 is available, please upgrade.
# --------
# IMPORTANT: You are using gradio version 3.50.2, however version 4.29.0 is available, please upgrade.
# --------
# IMPORTANT: You are using gradio version 3.50.2, however version 4.29.0 is available, please upgrade.
# --------
# ...

# %% [markdown]
# 脚本来源：[tonyff](https://github.com/dream80/roop_colab)
# 原项目：[facefusion](https://github.com/facefusion/facefusion)
# 关联脚本：[roop](https://colab.research.google.com/github/dream80/roop_colab/blob/main/roop_v1_3.ipynb)
#
#
#
# 公众号：托尼不是塔克
# 个人博客：[tonyisstark.com](https://www.tonyisstark.com)
